# %%
import streamlit as st
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(
    np.random.rand(20, 3),
    columns=['a', 'b', 'c']
)
df
# Out:
#            a         b         c
# 0   0.665440  0.188588  0.140418
# 1   0.970093  0.105828  0.726147
# 2   0.625225  0.748110  0.372912
# 3   0.808608  0.321500  0.994308
# 4   0.923787  0.824156  0.518146
# 5   0.299284  0.499122  0.033712
# 6   0.641988  0.782107  0.690607
# 7   0.807118  0.173980  0.643962
# 8   0.166766  0.897101  0.098888
# 9   0.626554  0.045736  0.104640
# 10  0.589570  0.222489  0.682007
# 11  0.850690  0.900579  0.471773
# 12  0.343543  0.848522  0.127791
# 13  0.065726  0.268101  0.215467
# 14  0.346212  0.990188  0.149877
# 15  0.730401  0.442682  0.930425
# 16  0.525307  0.008058  0.049026
# 17  0.694843  0.410035  0.257391
# 18  0.033799  0.876474  0.599926
# 19  0.093284  0.827123  0.458320
