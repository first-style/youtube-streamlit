# %%
import streamlit as st
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(
    np.random.rand(20, 3),
    columns=['a', 'b', 'c']
)
df
# Out:
#            a         b         c
# 0   0.724461  0.769590  0.854551
# 1   0.778866  0.277119  0.755019
# 2   0.574232  0.716868  0.288327
# 3   0.809489  0.956506  0.346718
# 4   0.010441  0.711882  0.083907
# 5   0.150270  0.086389  0.445773
# 6   0.542403  0.973608  0.843416
# 7   0.346935  0.707571  0.373022
# 8   0.693276  0.721015  0.912225
# 9   0.530835  0.750459  0.214269
# 10  0.819741  0.654552  0.546567
# 11  0.497983  0.133733  0.006206
# 12  0.998905  0.532662  0.793217
# 13  0.404782  0.707587  0.088790
# 14  0.777164  0.529648  0.236354
# 15  0.654673  0.951756  0.862367
# 16  0.022263  0.678091  0.876391
# 17  0.934547  0.896910  0.433576
# 18  0.711897  0.558993  0.312895
# 19  0.322122  0.831651  0.218968
